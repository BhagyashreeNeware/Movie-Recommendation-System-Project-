# %%
pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26800 sha256=f45d9351869fd5367d8c079677241d11f27f06945a1c8fc654e1a92fbbcd1865
#   Stored in directory: c:\users\bhagyashree\appdata\local\pip\cache\wheels\68\5d\a5\edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from pandasql import sqldf

# %%
df = pd.read_csv(r"C:\movies.csv")

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df1 = pd.read_csv(r"C:credits.csv")

# %%
df1
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
movies = pd.merge(df,df1)

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
a = "select * from movies"
a=sqldf(a)
print(a)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
b = "select avg(budget) from movies"
c = sqldf(b)
print(c)
# Out:
#     avg(budget)
# 0  2.902780e+07

# %%
d = "SELECT title, popularity from movies order by popularity desc limit 10"
d = sqldf(d)
print(d)
# Out:
#                                                title  popularity
# 0                                            Minions  875.581305
# 1                                       Interstellar  724.247784
# 2                                           Deadpool  514.569956
# 3                            Guardians of the Galaxy  481.098624
# 4                                 Mad Max: Fury Road  434.278564
# 5                                     Jurassic World  418.708552
# 6  Pirates of the Caribbean: The Curse of the Bla...  271.972889
# 7                     Dawn of the Planet of the Apes  243.791743
# 8              The Hunger Games: Mockingjay - Part 1  206.227151
# 9                                         Big Hero 6  203.734590

# %%
e = "SELECT title, popularity ,budget from movies order by popularity desc limit 10"
e = sqldf(e)
print(e)
# Out:
#                                                title  popularity     budget
# 0                                            Minions  875.581305   74000000
# 1                                       Interstellar  724.247784  165000000
# 2                                           Deadpool  514.569956   58000000
# 3                            Guardians of the Galaxy  481.098624  170000000
# 4                                 Mad Max: Fury Road  434.278564  150000000
# 5                                     Jurassic World  418.708552  150000000
# 6  Pirates of the Caribbean: The Curse of the Bla...  271.972889  140000000
# 7                     Dawn of the Planet of the Apes  243.791743  170000000
# 8              The Hunger Games: Mockingjay - Part 1  206.227151  125000000
# 9                                         Big Hero 6  203.734590  165000000

# %%
f = "SELECT title, AVG(vote_count) AS avg_vote FROM movies GROUP BY title ORDER BY avg_vote DESC"
f = sqldf(f)
print(f)
# Out:
#                             title  avg_vote
# 0                       Inception   13752.0
# 1                 The Dark Knight   12002.0
# 2                          Avatar   11800.0
# 3                    The Avengers   11776.0
# 4                        Deadpool   10995.0
# ...                           ...       ...
# 4795     Amidst the Devil's Wings       0.0
# 4796               American Beast       0.0
# 4797   America Is Still the Place       0.0
# 4798  A Beginner's Guide to Snuff       0.0
# 4799                       8 Days       0.0
#
# [4800 rows x 2 columns]

# %%
f = "SELECT title,vote_count, AVG(vote_count) AS avg_vote FROM movies GROUP BY title ORDER BY avg_vote DESC"
f = sqldf(f)
print(f)
# Out:
#                             title  vote_count  avg_vote
# 0                       Inception       13752   13752.0
# 1                 The Dark Knight       12002   12002.0
# 2                          Avatar       11800   11800.0
# 3                    The Avengers       11776   11776.0
# 4                        Deadpool       10995   10995.0
# ...                           ...         ...       ...
# 4795     Amidst the Devil's Wings           0       0.0
# 4796               American Beast           0       0.0
# 4797   America Is Still the Place           0       0.0
# 4798  A Beginner's Guide to Snuff           0       0.0
# 4799                       8 Days           0       0.0
#
# [4800 rows x 3 columns]

# %%
g = "SELECT id, COUNT(*) AS budget FROM movies GROUP BY title ORDER BY id asc"
g = sqldf(g)
print(g)
# Out:
#           id  budget
# 0          5       1
# 1         11       1
# 2         12       1
# 3         13       1
# 4         14       1
# ...      ...     ...
# 4795  426067       1
# 4796  426469       1
# 4797  433715       1
# 4798  447027       1
# 4799  459488       1
#
# [4800 rows x 2 columns]

# %%
h = "select distinct(vote_average) from movies"
h = sqldf(h)
print(h)
# Out:
#     vote_average
# 0            7.2
# 1            6.9
# 2            6.3
# 3            7.6
# 4            6.1
# ..           ...
# 66           2.0
# 67           2.8
# 68           9.5
# 69           2.6
# 70           2.4
#
# [71 rows x 1 columns]

# %%
i = "SELECT id, AVG(vote_count) AS avg_vote FROM movies GROUP BY vote_average ORDER BY avg_vote DESC"
i = sqldf(i)
print(i)
# Out:
#         id     avg_vote
# 0      550  4800.714286
# 1      278  4103.500000
# 2   157336  4035.444444
# 3      155  3287.866667
# 4   118340  3194.593750
# ..     ...          ...
# 66   89861     1.250000
# 67  224569     1.000000
# 68   10914     1.000000
# 69  239897     1.000000
# 70  310706     0.015873
#
# [71 rows x 2 columns]

# %%
-- Most popular genres


-- Average ratings per genre
SELECT genre, AVG(rating) AS avg_rating
FROM movies
JOIN user_ratings ON movies.movie_id = user_ratings.movie_id
GROUP BY genre
ORDER BY avg_rating DESC;

# %%
# -- Most popular genres
j = "SELECT genres, COUNT(*) AS num_ratings FROM movies GROUP BY genres ORDER BY num_ratings DESC"
j = sqldf(j)
print(j)
# Out:
#                                                  genres  num_ratings
# 0                         [{"id": 18, "name": "Drama"}]          372
# 1                        [{"id": 35, "name": "Comedy"}]          282
# 2     [{"id": 18, "name": "Drama"}, {"id": 10749, "n...          164
# 3     [{"id": 35, "name": "Comedy"}, {"id": 10749, "...          144
# 4     [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...          142
# ...                                                 ...          ...
# 1170  [{"id": 10402, "name": "Music"}, {"id": 27, "n...            1
# 1171  [{"id": 10402, "name": "Music"}, {"id": 18, "n...            1
# 1172  [{"id": 10402, "name": "Music"}, {"id": 18, "n...            1
# 1173  [{"id": 10402, "name": "Music"}, {"id": 18, "n...            1
# 1174  [{"id": 10402, "name": "Music"}, {"id": 12, "n...            1
#
# [1175 rows x 2 columns]

# %%
#-- Average voting per genres
h = "SELECT genres, AVG(vote_count) AS avg_vote FROM movies GROUP BY genres ORDER BY avg_vote DESC"
h = sqldf(h)
print(h)
# Out:
#                                                  genres  avg_vote
# 0     [{"id": 28, "name": "Action"}, {"id": 53, "nam...   13752.0
# 1     [{"id": 18, "name": "Drama"}, {"id": 28, "name...   12002.0
# 2     [{"id": 878, "name": "Science Fiction"}, {"id"...    9455.0
# 3     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    7458.0
# 4     [{"id": 18, "name": "Drama"}, {"id": 12, "name...    7268.0
# ...                                                 ...       ...
# 1170  [{"id": 28, "name": "Action"}, {"id": 80, "nam...       1.0
# 1171  [{"id": 28, "name": "Action"}, {"id": 35, "nam...       1.0
# 1172  [{"id": 53, "name": "Thriller"}, {"id": 35, "n...       0.0
# 1173  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...       0.0
# 1174  [{"id": 28, "name": "Action"}, {"id": 35, "nam...       0.0
#
# [1175 rows x 2 columns]
